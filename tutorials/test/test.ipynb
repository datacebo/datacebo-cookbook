# %%
# check import

from sdv.multi_table import HSASynthesizer

# %%
from sdv.datasets.demo import download_demo

data, metadata = download_demo('multi_table', 'fake_hotels')

hsa = HSASynthesizer(metadata)
hsa.fit(data)
sampled = hsa.sample()
